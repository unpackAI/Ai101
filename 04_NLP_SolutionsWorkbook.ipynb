# %% [markdown]
# # 💻Week 4 Workbook of unpackAI ```DL101 Bootcamp```

# %% [markdown]
# ## 📕 Learning Objectives of the Week
#
# * Understand the fundamental process of building your own language model.

# %% [markdown]
# ## 🎸 Libraries & Dependencies needed

# %%
# !pip install -Uqq unpackai
# !pip install -q git+https://github.com/unpackai/unpackai
# !pip install -Uqq transformers==4.10.2
# !pip install -q datasets transformers[sentencepiece]
# Out:
#      |████████████████████████████████| 49 kB 2.2 MB/s
#      |████████████████████████████████| 85 kB 1.6 MB/s
#      |████████████████████████████████| 2.8 MB 5.3 MB/s
#      |████████████████████████████████| 596 kB 44.3 MB/s
#      |████████████████████████████████| 895 kB 34.9 MB/s
#      |████████████████████████████████| 3.3 MB 24.7 MB/s
#      |████████████████████████████████| 56 kB 4.5 MB/s
#      |████████████████████████████████| 290 kB 5.3 MB/s
#      |████████████████████████████████| 1.3 MB 35.8 MB/s
#      |████████████████████████████████| 125 kB 47.1 MB/s
#      |████████████████████████████████| 243 kB 44.9 MB/s
#      |████████████████████████████████| 271 kB 44.8 MB/s
#      |████████████████████████████████| 160 kB 46.0 MB/s
#      |████████████████████████████████| 1.1 MB 48.8 MB/s

# %%
import torch
import numpy as np
from transformers import (
    AutoTokenizer,
    AutoModel,
    pipeline,
    set_seed,
    Trainer,
    TextDataset,
    DataCollatorForLanguageModeling,
    TrainingArguments,
    AutoModelForSequenceClassification,
)
from unpackai.nlp import Textual, InterpEmbeddingsTokenizer
from ipywidgets import interact
import logging
from fastai import *

# %% [markdown]
# ## unpackAI Assignment Section
#
#
# *   **Assignment 1**: Go through the multiple choice questions below and choose the correct answer. Discuss your answers during the presentation session.
# *   **Assignment 2**: Build an entire language model starting from defining your objective, gathering data to training your model and interpreting the results.

# %% [markdown]
# ## Assigment 1: Multiple choice questions.

# %% [markdown]
# 1. What is a Language Model?
#
# > A: A model that can talk.
#
# > B: A model that is able to generate text by copying and pasting different sections of text that it was trained on.
#
# > C: A model that is able to predict the most likely next word in a sequence of words.

# %% [markdown]
# 2. What is Tokenization in NLP?
#
# > A: Tokenization is the process of turning sensitive data into nonsensitive data called "tokens" that can be used in a database or internal system without bringing it into scope.
#
# > B: Tokenization is a technique to split words, numbers, commas etc. into sub units to allow for further processing.
#
# > C: Tokenization is a technique split the text dataset into a tokenized validation or training dataset.

# %% [markdown]
# 3. What are word-embeddings?
#
# > A: Word embeddings are a type of word representation that allows words with similar meaning to have a similar representation.
#
# > B: Word embeddings score the meaningfulness of a word. The higher the value of the learned features within a word-embeddings the more meaningful & important it is within the text dataset.
#
# > C: A word embedding is a learned feature of a word. This feature describes every word with a number between 1 and -1.

# %% [markdown]
# ## Assignment 2: Build an entire Language Model.

# %% [markdown]
# ### Step One - Define a ML problem and propose a solution.

# %% [markdown]
# #### 1. Define the objective
# **Your objective:**
# > Build a Language Model than can create the text of a poem.
# #### 2. Describe your dataset
# **Your dataset:**
# > THE HUNDRED BEST ENGLISH POEMS including authors such as Shakespeare. 29 thousand words. 100 poems. Gutenberg txt file.
# #### 3. Describe your model
# **Your model:**
# > Transformer Model to generate text it was pretrained on, based on an initial set of words that I provide.

# %% [markdown]
# ### Step Two - Collect and construct your dataset
#
# In order to collect and design your own dataset we provide you with the `Textual` scraping tool below. For that you have two options!

# %% [markdown]
# **Option 1: Collect text from an URL.**
#
# Provide an URL to the textual tool and all the text will be collected. We recommend [Gutenberg Project](https://gutenberg.org/) as a source which is a collection of over 60,000 free eBooks. Simply click on a book that you like and the corresponding txt file (see image below).
#
# <img src="https://www.dropbox.com/s/p5tyklp58d3yosa/Screen%20Shot%202021-09-13%20at%2017.49.52.png?dl=1" alt="wordembeddings" width="500"/>
#
# However, feel free to experiment with other datasets from other URL sources.

# %%
textual = Textual.from_url("https://www.gutenberg.org/cache/epub/17768/pg17768.txt")
textual
# Out:
# Text (173339 chars), textual(),
#     train_path, val_path = textual.create_train_val()

# %%
textual()
# Out:
# interactive(children=(IntSlider(value=86, description='page', max=172), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# ### Step Three - Model Training

# %% [markdown]
# We skip the Data Transformation as the Tokenization and Numericalisation happens during the Model Training.

# %%
pretrained_model = pipeline("text-generation", model='gpt2')
# Out:
# DEBUG:filelock:Attempting to acquire lock 139633816022224 on /root/.cache/huggingface/transformers/fc674cd6907b4c9e933cb42d67662436b89fa9540a1f40d7c919d0109289ad01.7d2e0efa5ca20cef4fb199382111e9d3ad96fd77b849e1d4bed13a66e1336f51.lock
# DEBUG:filelock:Lock 139633816022224 acquired on /root/.cache/huggingface/transformers/fc674cd6907b4c9e933cb42d67662436b89fa9540a1f40d7c919d0109289ad01.7d2e0efa5ca20cef4fb199382111e9d3ad96fd77b849e1d4bed13a66e1336f51.lock
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139633816022224 on /root/.cache/huggingface/transformers/fc674cd6907b4c9e933cb42d67662436b89fa9540a1f40d7c919d0109289ad01.7d2e0efa5ca20cef4fb199382111e9d3ad96fd77b849e1d4bed13a66e1336f51.lock
# DEBUG:filelock:Lock 139633816022224 released on /root/.cache/huggingface/transformers/fc674cd6907b4c9e933cb42d67662436b89fa9540a1f40d7c919d0109289ad01.7d2e0efa5ca20cef4fb199382111e9d3ad96fd77b849e1d4bed13a66e1336f51.lock
# DEBUG:filelock:Attempting to acquire lock 139633756438480 on /root/.cache/huggingface/transformers/752929ace039baa8ef70fe21cdf9ab9445773d20e733cf693d667982e210837e.323c769945a351daa25546176f8208b3004b6f563438a7603e7932bae9025925.lock
# DEBUG:filelock:Lock 139633756438480 acquired on /root/.cache/huggingface/transformers/752929ace039baa8ef70fe21cdf9ab9445773d20e733cf693d667982e210837e.323c769945a351daa25546176f8208b3004b6f563438a7603e7932bae9025925.lock
# Downloading:   0%|          | 0.00/548M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139633756438480 on /root/.cache/huggingface/transformers/752929ace039baa8ef70fe21cdf9ab9445773d20e733cf693d667982e210837e.323c769945a351daa25546176f8208b3004b6f563438a7603e7932bae9025925.lock
# DEBUG:filelock:Lock 139633756438480 released on /root/.cache/huggingface/transformers/752929ace039baa8ef70fe21cdf9ab9445773d20e733cf693d667982e210837e.323c769945a351daa25546176f8208b3004b6f563438a7603e7932bae9025925.lock
# DEBUG:filelock:Attempting to acquire lock 139633755808976 on /root/.cache/huggingface/transformers/684fe667923972fb57f6b4dcb61a3c92763ad89882f3da5da9866baf14f2d60f.c7ed1f96aac49e745788faa77ba0a26a392643a50bb388b9c04ff469e555241f.lock
# DEBUG:filelock:Lock 139633755808976 acquired on /root/.cache/huggingface/transformers/684fe667923972fb57f6b4dcb61a3c92763ad89882f3da5da9866baf14f2d60f.c7ed1f96aac49e745788faa77ba0a26a392643a50bb388b9c04ff469e555241f.lock
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139633755808976 on /root/.cache/huggingface/transformers/684fe667923972fb57f6b4dcb61a3c92763ad89882f3da5da9866baf14f2d60f.c7ed1f96aac49e745788faa77ba0a26a392643a50bb388b9c04ff469e555241f.lock
# DEBUG:filelock:Lock 139633755808976 released on /root/.cache/huggingface/transformers/684fe667923972fb57f6b4dcb61a3c92763ad89882f3da5da9866baf14f2d60f.c7ed1f96aac49e745788faa77ba0a26a392643a50bb388b9c04ff469e555241f.lock
# DEBUG:filelock:Attempting to acquire lock 139633755852368 on /root/.cache/huggingface/transformers/c0c761a63004025aeadd530c4c27b860ec4ecbe8a00531233de21d865a402598.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:filelock:Lock 139633755852368 acquired on /root/.cache/huggingface/transformers/c0c761a63004025aeadd530c4c27b860ec4ecbe8a00531233de21d865a402598.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139633755852368 on /root/.cache/huggingface/transformers/c0c761a63004025aeadd530c4c27b860ec4ecbe8a00531233de21d865a402598.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:filelock:Lock 139633755852368 released on /root/.cache/huggingface/transformers/c0c761a63004025aeadd530c4c27b860ec4ecbe8a00531233de21d865a402598.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:filelock:Attempting to acquire lock 139633755852368 on /root/.cache/huggingface/transformers/16a2f78023c8dc511294f0c97b5e10fde3ef9889ad6d11ffaa2a00714e73926e.cf2d0ecb83b6df91b3dbb53f1d1e4c311578bfd3aa0e04934215a49bf9898df0.lock
# DEBUG:filelock:Lock 139633755852368 acquired on /root/.cache/huggingface/transformers/16a2f78023c8dc511294f0c97b5e10fde3ef9889ad6d11ffaa2a00714e73926e.cf2d0ecb83b6df91b3dbb53f1d1e4c311578bfd3aa0e04934215a49bf9898df0.lock
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139633755852368 on /root/.cache/huggingface/transformers/16a2f78023c8dc511294f0c97b5e10fde3ef9889ad6d11ffaa2a00714e73926e.cf2d0ecb83b6df91b3dbb53f1d1e4c311578bfd3aa0e04934215a49bf9898df0.lock
# DEBUG:filelock:Lock 139633755852368 released on /root/.cache/huggingface/transformers/16a2f78023c8dc511294f0c97b5e10fde3ef9889ad6d11ffaa2a00714e73926e.cf2d0ecb83b6df91b3dbb53f1d1e4c311578bfd3aa0e04934215a49bf9898df0.lock

# %%
arguments = TrainingArguments(
    output_dir="./write_style",
    overwrite_output_dir=True,  
    num_train_epochs=3,
    per_device_train_batch_size=24,
    per_device_eval_batch_size=64,
    )

# %%
trainer = textual.get_hf_trainer(
    model=pretrained_model.model,
    tokenizer = pretrained_model.tokenizer,
    arguments = arguments
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/data/datasets/language_modeling.py:58: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/master/examples/pytorch/language-modeling/run_mlm.py
#   FutureWarning,
# DEBUG:filelock:Attempting to acquire lock 140506983491920 on ./cached_lm_DistilBertTokenizerFast_126_train_text.txt.lock
# DEBUG:filelock:Lock 140506983491920 acquired on ./cached_lm_DistilBertTokenizerFast_126_train_text.txt.lock
# Token indices sequence length is longer than the specified maximum sequence length for this model (34676 > 512). Running this sequence through the model will result in indexing errors
# DEBUG:filelock:Attempting to release lock 140506983491920 on ./cached_lm_DistilBertTokenizerFast_126_train_text.txt.lock
# DEBUG:filelock:Lock 140506983491920 released on ./cached_lm_DistilBertTokenizerFast_126_train_text.txt.lock
# DEBUG:filelock:Attempting to acquire lock 140512720321808 on ./cached_lm_DistilBertTokenizerFast_126_val_text.txt.lock
# DEBUG:filelock:Lock 140512720321808 acquired on ./cached_lm_DistilBertTokenizerFast_126_val_text.txt.lock
# DEBUG:filelock:Attempting to release lock 140512720321808 on ./cached_lm_DistilBertTokenizerFast_126_val_text.txt.lock
# DEBUG:filelock:Lock 140512720321808 released on ./cached_lm_DistilBertTokenizerFast_126_val_text.txt.lock

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 275
#   Num Epochs = 3
#   Instantaneous batch size per device = 24
#   Total train batch size (w. parallel, distributed & accumulation) = 24
#   Gradient Accumulation steps = 1
#   Total optimization steps = 36
# <div>
#     <html>
#     <head>
#         <meta name="viewport"
#         content="width=device-width, initial-scale=1">
#     </head>
#     <body>
#         <a download="npakai_TypeError_1026_121038.html" href="data:text/html;base64,..." >
#     <button class="p-Widget jupyter-widgets jupyter-button widget-button mod-success">
#         🦋 Download Report</button>
#     </a>
#     </body>
# </html> <span>Download error report and consult a mentor/TA</span>
# </div>
# <h2>🐞 [TypeError] Happened, Don't Panic</h2>
#
# <h3>🤔 Default message:</h3>
# <hr>
# <quote>
#     forward() got an unexpected keyword argument 'labels'
# </quote>
# <hr>
# <h3>Traceback Info</h3>
# Traceback (most recent call last):
#   File "<ipython-input-8-3435b262f1ae>", line 1, in <module>
#     trainer.train()
#   File "/usr/local/lib/python3.7/dist-packages/transformers/trainer.py", line 1284, in train
#     tr_loss += self.training_step(model, inputs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/trainer.py", line 1789, in training_step
#     loss = self.compute_loss(model, inputs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/trainer.py", line 1821, in compute_loss
#     outputs = model(**inputs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
# TypeError: forward() got an unexpected keyword argument 'labels'

# %%
trainer.save_model()

# %% [markdown]
# ### Step Four - Interpret the model and generate text.

# %%
style_writer = pipeline('text-generation',
                        model='./write_style',
                        tokenizer=pretrained_model.tokenizer
                        )

# %%
style_writer("To be or not to be",
            max_length=100,
            num_return_sequences=1)
# Out:
# Using pad_token, but it is not set yet.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'To be or not to be! That is that which must be a gift from God, and to what belongs to us... * He says: When, the Father is born, and when they die, the Son shall live.  When the Son shall die they shall live--they shall all be born, and all their life shall be. But as for me, my soul                        '}]
